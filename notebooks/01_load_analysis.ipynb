# %%
import pandas as pd
import matplotlib.pyplot as plt # Importation de la bibliothèque pour création et visualisation de graphiques

#charger les données
df = pd.read_csv("../data/profil_charge_tertiaire.csv")

#Convertir en datetime
#df["datetime"] = pd.to_datetime(df["datetime"]) #Convertit la colonne datetime en format datetime de pandas

#Mettre la colonne datetime en index
#df.set_index("datetime", inplace=True)

df.head()
# Out:
#     power_kW
# 0  52.567697
# 1  81.306701
# 2  89.562543
# 3  87.670179
# 4  55.019340

# %%
print("Nombre de lignes : ", len(df))
print("Valeur max :", df["power_kW"].max())
print("Valeur min :", df["power_kW"].min())
print("Moyenne :", df["power_kW"].mean())
# Out:
# Nombre de lignes :  8737
# Valeur max : 535.5760527542544
# Valeur min : 0.0
# Moyenne : 250.74555291529543

# %%
df_week = df["2023-03-01":"2023-03-07"]
              
plt.figure(figsize=(12,4))
plt.plot(df_week.index, df_week["power_kW"])
plt.title("Profil de charge du 1er au 7 mars 2023")
plt.ylabel("kW")
plt.xticks (rotation=45) #Fait pivoter les dates pour une meilleure lisibilité
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df_week = df["2023-03-01":"2023-03-07"]
#       3 plt.figure(figsize=(12,4))
#       4 plt.plot(df_week.index, df_week["power_kW"])
#
# File c:\Users\ASUS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\frame.py:4096, in DataFrame.__getitem__(self, key)
#    4094 # Do we have a slicer (on rows)?
#    4095 if isinstance(key, slice):
# -> 4096     return self._getitem_slice(key)
#    4098 # Do we have a (boolean) DataFrame?
#    4099 if isinstance(key, DataFrame):
#
# File c:\Users\ASUS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\generic.py:4371, in NDFrame._getitem_slice(self, key)
#    4366 """
#    4367 __getitem__ for the case where the key is a slice object.
#    4368 """
#    4369 # _convert_slice_indexer to determine if this slice is positional
#    4370 #  or label based, and if the latter, convert to positional
# -> 4371 slobj = self.index._convert_slice_indexer(key, kind="getitem")
#    4372 if isinstance(slobj, np.ndarray):
#    4373     # reachable with DatetimeIndex
#    4374     indexer = lib.maybe_indices_to_slice(
#    4375         slobj.astype(np.intp, copy=False), len(self)
#    4376     )
#
# File c:\Users\ASUS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexes\base.py:4255, in Index._convert_slice_indexer(self, key, kind)
#    4252     return key
#    4253 elif self.dtype.kind in "iu":
#    4254     # Note: these checks are redundant if we know is_index_slice
# -> 4255     self._validate_indexer("slice", key.start, "getitem")
#    4256     self._validate_indexer("slice", key.stop, "getitem")
#    4257     self._validate_indexer("slice", key.step, "getitem")
#
# File c:\Users\ASUS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexes\base.py:6752, in Index._validate_indexer(self, form, key, kind)
#    6747 """
#    6748 If we are positional indexer, validate that we have appropriate
#    6749 typed bounds must be an integer.
#    6750 """
#    6751 if not lib.is_int_or_none(key):
# -> 6752     self._raise_invalid_indexer(form, key)
#
# File c:\Users\ASUS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexes\base.py:4308, in Index._raise_invalid_indexer(self, form, key, reraise)
#    4306 if reraise is not lib.no_default:
#    4307     raise TypeError(msg) from reraise
# -> 4308 raise TypeError(msg)
#
# TypeError: cannot do slice indexing on RangeIndex with these indexers [2023-03-01] of type str

# %%
df_day = df.loc["2023-03-01"]

plt.figure(figsize=(8,4))
plt.plot(df_day.index, df_day["power_kW"])
plt.title("Profil de charge du 1er mars 2023")
plt.ylabel("kW")
plt.xticks (rotation=45)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df_day = df.loc["2023-03-01"]
#       3 plt.figure(figsize=(8,4))
#       4 plt.plot(df_day.index, df_day["power_kW"])
#
# File c:\Users\ASUS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexing.py:1192, in _LocationIndexer.__getitem__(self, key)
#    1190 maybe_callable = com.apply_if_callable(key, self.obj)
#    1191 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1192 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\ASUS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexing.py:1432, in _LocIndexer._getitem_axis(self, key, axis)
#    1430 # fall thru to straight lookup
#    1431 self._validate_key(key, axis)
# -> 1432 return self._get_label(key, axis=axis)
#
# File c:\Users\ASUS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexing.py:1382, in _LocIndexer._get_label(self, label, axis)
#    1380 def _get_label(self, label, axis: AxisInt):
#    1381     # GH#5567 this will fail if the label is not present in the axis.
# -> 1382     return self.obj.xs(label, axis=axis)
#
# File c:\Users\ASUS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\generic.py:4323, in NDFrame.xs(self, key, axis, level, drop_level)
#    4321             new_index = index[loc]
#    4322 else:
# -> 4323     loc = index.get_loc(key)
#    4325     if isinstance(loc, np.ndarray):
#    4326         if loc.dtype == np.bool_:
#
# File c:\Users\ASUS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexes\range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: '2023-03-01'

# %%
peak_power = df["power_kW"].max()
mean_power = df["power_kW"].mean()
annual_energy = df["power_kW"].sum()  # Mesurer la consommation en kWh

load_factor = mean_power / peak_power # mesurer le facteur de charge

print(f"Pic de puissance : {peak_power:.1f} kW")
print(f"Puissance moyenne : {mean_power:.1f} kW")
print(f"Énergie annuelle : {annual_energy:.0f} kWh")
print(f"Facteur de charge : {load_factor:.2f}")
# Out:
# Pic de puissance : 539.5 kW
# Puissance moyenne : 251.0 kW
# Énergie annuelle : 2193200 kWh
# Facteur de charge : 0.47

# %%
treshold = 0.8*peak_power
high_load_hours = df[df["power_kW"] > treshold]
print("Nombre d'heures > 80% du pic :", len(high_load_hours))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 treshold = 0.8*peak_power
#       2 high_load_hours = df[df["power_kW"] > treshold]
#       3 print("Nombre d'heures > 80% du pic :", len(high_load_hours))
#
# NameError: name 'peak_power' is not defined
